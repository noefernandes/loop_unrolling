# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
#sequencial
x = [0.00000380299999999667, 0.0000028200000000006, 0.000003374999999999906, 0.0000041590000000035765,
     0.000005002999999989544, 0.000006169999999999787, 0.000010243999999992592, 0.000012791999999997583,
     0.000043917000000004425, 0.00009202199999999716, 0.00015597599999998824, 0.00023933299999999436,
     0.0005227540000000003, 0.0009314379999999928]

#threads
y = [0.00011588600000000948,0.0004419050000000063,0.0005205399999999999,0.0008616499999999916,
      0.0012690380000000001,0.0017820780000000064,0.0032752840000000033,0.005075773999999991,
     0.021415106000000003,0.047704951999999995,0.08273795499999997,0.129933739,0.29661282899999997,
    0.5289415399999999]

fig, ax= plt.subplots(figsize=(9,5))

ax.set_xticks(range(0, 14))


ax.set_xticklabels(['1', '2', '3', '4', '5', '6', '7', '8', '10', '20', '40', '50', '75','100'])
ax.plot(list(range(14)), x, c='blue', label='Sequencial')
ax.plot(list(range(14)), y, c='red', label='Threads')
ax.legend()
ax.set_xlabel('Ordem da matriz')
ax.set_ylabel("Tempo de execução (s)")
plt.title("Tempo de execução da soma de acordo com a ordem da matriz")
plt.show()

# %%
#sequencial
x = [0.000003394000000003783, 0.0000019639999999931934, 0.000002014000000008509, 0.0000019859999999954914,
    0.0000031030000000042968, 0.0000028710000000015112, 0.0000028890000000059146, 0.0000060139999999986316,
    0.000006412999999996782, 0.000008275999999987627, 0.000010441999999999396, 0.000013171000000006261, 
    0.0000184569999999995, 0.00002394499999999700]

#threads
y = [0.000003376999999998853, 0.0000014589999999953251, 0.000001222999999994645, 0.0000011410000000100506,
    0.0000023479999999992396, 0.0000019069999999954401, 0.0000013910000000033618, 0.0000012350000000022066,
    0.0000017329999999898815, 0.0000015450000000055697, 0.000001634999999999831, 0.0000016619999999994972,
    0.0000016200000000077264, 0.0000016770000000054797]


fig, ax= plt.subplots(figsize=(9,5))

ax.set_xticks(range(0, 14))


ax.set_xticklabels(['1', '2', '3', '4', '5', '6', '7', '8', '10', '20', '40', '50', '75','100'])
ax.plot(list(range(14)), x, c='blue', label='Sequencial')
ax.plot(list(range(14)), y, c='red', label='Threads')
ax.legend()
ax.set_xlabel('Ordem da matriz')
ax.set_ylabel("Tempo de execução (s)")
plt.title("Tempo de execução da multiplicação de acordo com a ordem da matriz")
plt.show()

# %%
# Adição
seq_matsum = np.genfromtxt('seq_matsum.txt', delimiter='\n') 
thr_matsum = np.genfromtxt('thr_matsum.txt', delimiter='\n') 
pro_matsum = np.genfromtxt('pro_matsum.txt', delimiter='\n') 

fig, ax= plt.subplots(figsize=(9,5))
ax.set_xticks(range(0, 14))
ax.set_xticklabels(['1', '2', '3', '4', '5', '6', '7', '8', '10', '20', '40', '50', '75','100'])
ax.plot(list(range(14)), seq_matsum, c='blue', label='Sequencial')
ax.plot(list(range(14)), thr_matsum, c='red', label='Threads')
ax.plot(list(range(14)), pro_matsum, c='green', label='Processos')
ax.legend()
ax.set_xlabel('Ordem da matriz')
ax.set_ylabel("Tempo de execução (s)")
plt.title("Tempo de execução da soma de acordo com a ordem da matriz")
plt.show()

# %%
# Produto
seq_matpro = np.genfromtxt('seq_matpro.txt', delimiter='\n') 
thr_matpro = np.genfromtxt('thr_matpro.txt', delimiter='\n') 
pro_matpro = np.genfromtxt('pro_matpro.txt', delimiter='\n') 

fig, ax= plt.subplots(figsize=(9,5))
ax.set_xticks(range(0, 14))
ax.set_xticklabels(['1', '2', '3', '4', '5', '6', '7', '8', '10', '20', '40', '50', '75','100'])
ax.plot(list(range(14)), seq_matsum, c='blue', label='Sequencial')
ax.plot(list(range(14)), thr_matsum, c='red', label='Threads')
ax.plot(list(range(14)), pro_matsum, c='green', label='Processos')
ax.legend()
ax.set_xlabel('Ordem da matriz')
ax.set_ylabel("Tempo de execução (s)")
plt.title("Tempo de execução do produto de acordo com a ordem da matriz")
plt.show()
